# %%
# !pip install apyori
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=6015 sha256=539fe04c3fde39710cd1f55aaa3c0819096accf847645e3609a57377cb0e934a
#   Stored in directory: c:\users\ayush\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local\pip\cache\wheels\4d\9f\d0\7ba4ae3f5de2f76ea362170ea0f157e6cc1d1b9aea188175f2
# Successfully built apyori
# ...
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\ayush\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages)
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from apyori import apriori

# %%
df = pd.read_csv("store_data.csv",header=None)

# %%
df.shape
# Out:
# (7501, 20)

# %%
# converting pandas dataframe in list of lists
records = []
for i in range(0,7500):
    records.append([str(df.values[i,j]) for j in range(0,20)])
