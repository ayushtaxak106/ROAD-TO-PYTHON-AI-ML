# %% [markdown]
# #hash table

# %% [markdown]
# A hash table is a data structure that stores information as key-value pairs. It uses a special hash function to convert a key directly into a memory address or index. This allows for incredibly fast data lookups, insertions, and deletions. 🚀

# %% [markdown]
# hash table is faster than arrays
#
# dict is faster than numpy arrays

# %%
! pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.3.1

# %%
nums = pd.Series([10,20,30,40,50])
print(nums)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %% [markdown]
# get will help if there is some value of index that is not present in our data then will not throw an error but simply return none

# %%
print(nums.get(0))
print(nums.get(6))
# Out:
# 10
# None

# %%
data = {
    'cars': ['bmw','mercedez','tata'],
    'bikes': ['honda','tvs','hero']
}

# %%
dataframe = pd.DataFrame(data)
print(dataframe)
# Out:
#        cars  bikes
# 0       bmw  honda
# 1  mercedez    tvs
# 2      tata   hero
